# %% [markdown]
# <a href="https://colab.research.google.com/github/J-o-y-y/codeslave/blob/main/3_5_while.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3.5 while :

# %%
"""

from random import randint
user_choice = int(input("Choose number:")) 
pc_choice = randint(1,50)

if user_choice == pc_choice:
  print("You won!")
elif user_choice > pc_choice:
  print("Lower! Computer cose", pc_choice)
elif user_choice < pc_choice:
  print("Higher! Computer cose", pc_choice)

  """

while True:
    print("Hi im True")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# Hi im True
# ...

# %%
distance = 0

while distance < 20:
  print("I'm running:", distance, "km")
  distance = distance + 1
# Out:
# I'm running: 0 km
# I'm running: 1 km
# I'm running: 2 km
# I'm running: 3 km
# I'm running: 4 km
# I'm running: 5 km
# I'm running: 6 km
# I'm running: 7 km
# I'm running: 8 km
# I'm running: 9 km
# I'm running: 10 km
# I'm running: 11 km
# I'm running: 12 km
# I'm running: 13 km
# I'm running: 14 km
# I'm running: 15 km
# I'm running: 16 km
# I'm running: 17 km
# I'm running: 18 km
# I'm running: 19 km
