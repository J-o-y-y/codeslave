# %% [markdown]
# <a href="https://colab.research.google.com/github/J-o-y-y/codeslave/blob/main/Python_Programming_for_Pattern_Printing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range(0, 6):
    for j in range(0, i+1):
        print("* ",end="")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = 6
for i in range(n):
    for j in range(n - i - 1):
        print(" ", end="")
    for k in range(i + 1):
        print("* ", end="")
    print()
# Out:
#      *
#     * *
#    * * *
#   * * * *
#  * * * * *
# * * * * * *

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = 6

for i in range(n, 0, -1):
    for j in range(i):
        print("*", end=" ")
    print()
# Out:
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = 6
for i in range(n):
    for j in range(i):
        print(" ", end="")
    for k in range(n - i):
        print("* ", end="")
    print()
# Out:
# * * * * * *
#  * * * * *
#   * * * *
#    * * *
#     * *
#      *
